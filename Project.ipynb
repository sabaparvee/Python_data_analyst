# %% [markdown]
# **Overview
# You are a data analyst and your client has a large ecommerce company in India (let’s call it X).
# X gets a thousand orders via their website on a daily basis and they have to deliver them as fast
# as they can. For delivering the goods ordered by the customers, X has tied up with multiple
# courier companies in India as delivery partners who charge them some amount per delivery.
# The charges are dependent upon two factors:
# ● Weight of the product and the Price of the product.
# ● Distance between the warehouse (pickup location) and customer’s delivery address
# (destination location)
# On an average, the delivery charges are Rs. 100 per shipment. So if X ships 1,00,000 orders
# per month, they have to pay approximately Rs. 1 crore to the courier companies on a monthly
# basis as charges.
# As the amount that X has to pay to the courier companies is very high, they want to verify if the
# charges levied by their Delivery partners per Order are correct.**

# %% [markdown]
# ### IMPORT LIBRARY

# %%
import numpy as np
import pandas as pd
import math
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### UPLOAD FILES

# %%
df=pd.read_excel("Company X - Order Report.xlsx")

# %%
sk=pd.read_excel("Company X - SKU Master.xlsx")

# %%
pin=pd.read_excel("Company X - Pincode Zones.xlsx")

# %%
cour=pd.read_excel("Courier Company - Invoice.xlsx")

# %%
cour_rates=pd.read_excel("Courier Company - Rates.xlsx")

# %%
df
# Out:
#      ExternOrderNo            SKU  Order Qty Payment Mode  \
# 0       2001827036  8904223818706          1          COD
# 1       2001827036  8904223819093          1          COD
# 2       2001827036  8904223819109          1          COD
# 3       2001827036  8904223818430          1          COD
# 4       2001827036  8904223819277          1          COD
# ..             ...            ...        ...          ...
# 395     2001806229  8904223818942          1          COD
# 396     2001806229  8904223818850          1          COD
# 397     2001806226  8904223818850          2          COD
# 398     2001806210  8904223816214          1          COD
# 399     2001806210  8904223818874          1          COD
#
#      Item Price(Per Qty.)
# 0                     233
# 1                     233
# 2                     233
# 3                     470
# 4                     233
# ..                    ...
# 395                   286
# 396                   563
# 397                  1125
# 398                   402
# 399                   922
#
# [400 rows x 5 columns]

# %%
sk
# Out:
#               SKU  Weight (g)
# 0   8904223815682         210
# 1   8904223815859         165
# 2   8904223815866         113
# 3   8904223815873          65
# 4   8904223816214         120
# ..            ...         ...
# 61  8904223819505         210
# 62  8904223819499         210
# 63  8904223819512         210
# 64  8904223819543         300
# 65     SACHETS001          10
#
# [66 rows x 2 columns]

# %% [markdown]
# **Renaming ExternOrderNo to Order ID**

# %%
df.rename(columns={'ExternOrderNo':'Order ID'}, inplace=True)

# %%
df
# Out:
#        Order ID            SKU  Order Qty Payment Mode  Item Price(Per Qty.)
# 0    2001827036  8904223818706          1          COD                   233
# 1    2001827036  8904223819093          1          COD                   233
# 2    2001827036  8904223819109          1          COD                   233
# 3    2001827036  8904223818430          1          COD                   470
# 4    2001827036  8904223819277          1          COD                   233
# ..          ...            ...        ...          ...                   ...
# 395  2001806229  8904223818942          1          COD                   286
# 396  2001806229  8904223818850          1          COD                   563
# 397  2001806226  8904223818850          2          COD                  1125
# 398  2001806210  8904223816214          1          COD                   402
# 399  2001806210  8904223818874          1          COD                   922
#
# [400 rows x 5 columns]

# %% [markdown]
# **We create dictionary here for payment mode with ExternOrderNo. This will be help us in last step for calculating COD**

# %%
din=df.set_index('Order ID')['Payment Mode'].to_dict()

# %%
din
# Out:
# {2001827036: 'COD',
#  2001825261: 'Prepaid',
#  2001823564: 'Prepaid',
#  2001822466: 'COD',
#  2001821995: 'Prepaid',
#  2001821766: 'COD',
#  2001821750: 'Prepaid',
#  2001821742: 'Prepaid',
#  2001821679: 'COD',
#  2001821502: 'Prepaid',
#  2001821284: 'COD',
#  2001821190: 'COD',
#  2001821185: 'COD',
#  2001820978: 'Prepaid',
#  2001820690: 'COD',
#  2001819252: 'Prepaid',
#  2001818390: 'COD',
#  2001817160: 'COD',
#  2001817093: 'COD',
#  2001816996: 'Prepaid',
#  2001816684: 'Prepaid',
#  2001816131: 'Prepaid',
#  2001815688: 'COD',
#  2001814580: 'COD',
#  2001813009: 'COD',
#  2001812941: 'COD',
#  2001812854: 'COD',
#  2001812838: 'COD',
#  2001812650: 'COD',
#  2001812195: 'Prepaid',
#  2001811809: 'Prepaid',
#  2001811604: 'COD',
#  2001811475: 'COD',
#  2001811466: 'Prepaid',
#  2001811363: 'Prepaid',
#  2001811306: 'Prepaid',
#  2001811305: 'COD',
#  2001811229: 'COD',
#  2001811192: 'Prepaid',
#  2001811153: 'Prepaid',
#  2001811058: 'Prepaid',
#  2001811039: 'Prepaid',
#  2001810697: 'COD',
#  2001810549: 'COD',
#  2001810281: 'COD',
#  2001810125: 'COD',
#  2001810104: 'COD',
#  2001809934: 'COD',
#  2001809917: 'COD',
#  2001809820: 'Prepaid',
#  2001809794: 'Prepaid',
#  2001809592: 'Prepaid',
#  2001809383: 'Prepaid',
#  2001809270: 'COD',
#  2001808992: 'COD',
#  2001808883: 'Prepaid',
#  2001808837: 'Prepaid',
#  2001808832: 'Prepaid',
#  2001808801: 'Prepaid',
#  2001808739: 'Prepaid',
#  2001808679: 'Prepaid',
#  2001808675: 'COD',
#  2001808585: 'COD',
#  2001808542: 'COD',
#  2001808507: 'Prepaid',
#  2001808475: 'Prepaid',
#  2001808295: 'COD',
#  2001808286: 'Prepaid',
#  2001808207: 'COD',
#  2001808118: 'Prepaid',
#  2001808102: 'Prepaid',
#  2001807981: 'COD',
#  2001807976: 'Prepaid',
#  2001807970: 'Prepaid',
#  2001807960: 'Prepaid',
#  2001807956: 'Prepaid',
#  2001807931: 'COD',
#  2001807930: 'Prepaid',
#  2001807852: 'Prepaid',
#  2001807814: 'Prepaid',
#  2001807785: 'Prepaid',
#  2001807613: 'COD',
#  2001807415: 'Prepaid',
#  2001807362: 'Prepaid',
#  2001807329: 'Prepaid',
#  2001807328: 'COD',
#  2001807290: 'Prepaid',
#  2001807241: 'Prepaid',
#  2001807186: 'Prepaid',
#  2001807084: 'COD',
#  2001807058: 'Prepaid',
#  2001807036: 'COD',
#  2001807012: 'Prepaid',
#  2001807004: 'Prepaid',
#  2001806968: 'Prepaid',
#  2001806885: 'COD',
#  2001806828: 'COD',
#  2001806823: 'COD',
#  2001806801: 'Prepaid',
#  2001806776: 'Prepaid',
#  2001806768: 'COD',
#  2001806735: 'Prepaid',
#  2001806733: 'Prepaid',
#  2001806726: 'COD',
#  2001806686: 'COD',
#  2001806652: 'COD',
#  2001806616: 'COD',
#  2001806575: 'COD',
#  2001806567: 'COD',
#  2001806547: 'COD',
#  2001806533: 'Prepaid',
#  2001806471: 'COD',
#  2001806458: 'Prepaid',
#  2001806446: 'Prepaid',
#  2001806408: 'Prepaid',
#  2001806338: 'Prepaid',
#  2001806304: 'Prepaid',
#  2001806273: 'COD',
#  2001806251: 'Prepaid',
#  2001806233: 'Prepaid',
#  2001806232: 'COD',
#  2001806229: 'COD',
#  2001806226: 'COD',
#  2001806210: 'COD'}

# %%
sk
# Out:
#               SKU  Weight (g)
# 0   8904223815682         210
# 1   8904223815859         165
# 2   8904223815866         113
# 3   8904223815873          65
# 4   8904223816214         120
# ..            ...         ...
# 61  8904223819505         210
# 62  8904223819499         210
# 63  8904223819512         210
# 64  8904223819543         300
# 65     SACHETS001          10
#
# [66 rows x 2 columns]

# %%
df
# Out:
#        Order ID            SKU  Order Qty Payment Mode  Item Price(Per Qty.)
# 0    2001827036  8904223818706          1          COD                   233
# 1    2001827036  8904223819093          1          COD                   233
# 2    2001827036  8904223819109          1          COD                   233
# 3    2001827036  8904223818430          1          COD                   470
# 4    2001827036  8904223819277          1          COD                   233
# ..          ...            ...        ...          ...                   ...
# 395  2001806229  8904223818942          1          COD                   286
# 396  2001806229  8904223818850          1          COD                   563
# 397  2001806226  8904223818850          2          COD                  1125
# 398  2001806210  8904223816214          1          COD                   402
# 399  2001806210  8904223818874          1          COD                   922
#
# [400 rows x 5 columns]

# %%
df[df['Order ID']==2001822466]
# Out:
#       Order ID            SKU  Order Qty Payment Mode  Item Price(Per Qty.)
# 16  2001822466  8904223819468          2          COD                  1205
# 17  2001822466  8904223819291          8          COD                  7814

# %% [markdown]
# ### MERGE sk file with df(order report)
#  inorder to get weight by SKU number

# %%
df1=df.merge(sk[['SKU','Weight (g)']],on='SKU')

# %%
df1
# Out:
#        Order ID            SKU  Order Qty Payment Mode  Item Price(Per Qty.)  \
# 0    2001827036  8904223818706          1          COD                   233
# 1    2001821995  8904223818706          1      Prepaid                   233
# 2    2001819252  8904223818706          1      Prepaid                   233
# 3    2001816996  8904223818706          1      Prepaid                   233
# 4    2001814580  8904223818706          1          COD                   233
# ..          ...            ...        ...          ...                   ...
# 396  2001806616  8904223819123          1          COD                   442
# 397  2001806567  8904223815804          1          COD                   834
# 398  2001806567  8904223818577          1          COD                   946
# 399  2001806408  8904223819437          2      Prepaid                  1843
# 400  2001806232  8904223818645          6          COD                  1673
#
#      Weight (g)
# 0           127
# 1           127
# 2           127
# 3           127
# 4           127
# ..          ...
# 396         250
# 397         160
# 398         150
# 399         552
# 400         137
#
# [401 rows x 6 columns]

# %% [markdown]
# **To get total weight**

# %%
df1['Total Weight']=df1['Order Qty']*df1['Weight (g)']

# %%
df1
# Out:
#        Order ID            SKU  Order Qty Payment Mode  Item Price(Per Qty.)  \
# 0    2001827036  8904223818706          1          COD                   233
# 1    2001821995  8904223818706          1      Prepaid                   233
# 2    2001819252  8904223818706          1      Prepaid                   233
# 3    2001816996  8904223818706          1      Prepaid                   233
# 4    2001814580  8904223818706          1          COD                   233
# ..          ...            ...        ...          ...                   ...
# 396  2001806616  8904223819123          1          COD                   442
# 397  2001806567  8904223815804          1          COD                   834
# 398  2001806567  8904223818577          1          COD                   946
# 399  2001806408  8904223819437          2      Prepaid                  1843
# 400  2001806232  8904223818645          6          COD                  1673
#
#      Weight (g)  Total Weight
# 0           127           127
# 1           127           127
# 2           127           127
# 3           127           127
# 4           127           127
# ..          ...           ...
# 396         250           250
# 397         160           160
# 398         150           150
# 399         552          1104
# 400         137           822
#
# [401 rows x 7 columns]

# %% [markdown]
# **Group Function**
#  Grouping Function is used here to get the Order qty,Item Price,Total Weight by OrderNo

# %%
df2=df1.groupby('Order ID')['Order Qty','Total Weight','Item Price(Per Qty.)'].sum()

# %%
df2
# Out:
#             Order Qty  Total Weight  Item Price(Per Qty.)
# Order ID
# 2001806210          2           220                  1324
# 2001806226          2           480                  1125
# 2001806229          3           500                  1082
# 2001806232          8          1302                  2139
# 2001806233          2           245                  1486
# ...               ...           ...                   ...
# 2001821995          2           477                   484
# 2001822466         10          1376                  9019
# 2001823564          6           672                  4803
# 2001825261         13          1557                  9049
# 2001827036         10          2176                  3640
#
# [124 rows x 3 columns]

# %%
df1[df1['Order ID']==2001825261]
# Out:
#        Order ID            SKU  Order Qty Payment Mode  Item Price(Per Qty.)  \
# 74   2001825261  8904223818638          3      Prepaid                   855
# 78   2001825261     SACHETS001          1      Prepaid                   350
# 80   2001825261  8904223819024          4      Prepaid                  3636
# 97   2001825261  8904223819291          4      Prepaid                  3907
# 106  2001825261  8904223818669          1      Prepaid                   301
#
#      Weight (g)  Total Weight
# 74          137           411
# 78           10            10
# 80          112           448
# 97          112           448
# 106         240           240

# %%
df[df['SKU']==8904223819024]
# Out:
#        Order ID            SKU  Order Qty Payment Mode  Item Price(Per Qty.)
# 8    2001825261  8904223819024          4      Prepaid                  3636
# 15   2001823564  8904223819024          2      Prepaid                  1818
# 28   2001821502  8904223819024          2      Prepaid                  1818
# 30   2001821284  8904223819024          1          COD                   909
# 58   2001817093  8904223819024          2          COD                  1818
# 86   2001812854  8904223819024          2          COD                  1818
# 127  2001811192  8904223819024          2      Prepaid                  1818
# 163  2001809820  8904223819024          2      Prepaid                  1818
# 180  2001809592  8904223819024          8      Prepaid                  7271
# 238  2001808102  8904223819024          2      Prepaid                  1818
# 277  2001807415  8904223819024          4      Prepaid                  3636
# 279  2001807362  8904223819024          6      Prepaid                  5454
# 282  2001807362  8904223819024          2      Prepaid                  1818
# 307  2001807036  8904223819024          4          COD                  3636
# 347  2001806616  8904223819024          1          COD                   909
# 354  2001806567  8904223819024          1          COD                   909
# 376  2001806408  8904223819024          8      Prepaid                  7271

# %% [markdown]
# **Adding index as column and drop index**

# %%
df2['Order ID']=df2.index

# %%
df2=df2.reset_index(drop=True)

# %%
df2
# Out:
#      Order Qty  Total Weight  Item Price(Per Qty.)    Order ID
# 0            2           220                  1324  2001806210
# 1            2           480                  1125  2001806226
# 2            3           500                  1082  2001806229
# 3            8          1302                  2139  2001806232
# 4            2           245                  1486  2001806233
# ..         ...           ...                   ...         ...
# 119          2           477                   484  2001821995
# 120         10          1376                  9019  2001822466
# 121          6           672                  4803  2001823564
# 122         13          1557                  9049  2001825261
# 123         10          2176                  3640  2001827036
#
# [124 rows x 4 columns]

# %%
cour
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 140.0
# 1              486886    d          Forward charges                 101.2
# 2              532484    d          Forward charges                 224.6
# 3              143001    b          Forward charges                  61.3
# 4              515591    d          Forward charges                  45.4
# ..                ...  ...                      ...                   ...
# 119            325207    d          Forward charges                  95.2
# 120            303702    d  Forward and RTO charges                  86.7
# 121            313301    d          Forward charges                  45.4
# 122            173212    b          Forward charges                  47.0
# 123            302020    d          Forward charges                  65.4
#
# [124 rows x 8 columns]

# %% [markdown]
# ### MERGE File df1 with cour
# inorder to get Customer Pincode and Type Of Shipment

# %%
newdf1=pd.merge(left=df2,right=cour,on='Order ID')

# %%
newdf1
# Out:
#      Order Qty  Total Weight  Item Price(Per Qty.)    Order ID       AWB Code  \
# 0            2           220                  1324  2001806210  1091117221940
# 1            2           480                  1125  2001806226  1091117222065
# 2            3           500                  1082  2001806229  1091117222080
# 3            8          1302                  2139  2001806232  1091117222124
# 4            2           245                  1486  2001806233  1091117222135
# ..         ...           ...                   ...         ...            ...
# 119          2           477                   484  2001821995  1091121183730
# 120         10          1376                  9019  2001822466  1091121305541
# 121          6           672                  4803  2001823564  1091121666133
# 122         13          1557                  9049  2001825261  1091121981575
# 123         10          2176                  3640  2001827036  1091122418320
#
#      Charged Weight  Warehouse Pincode  Customer Pincode Zone  \
# 0              2.92             121003            140604    b
# 1              0.68             121003            723146    d
# 2              0.71             121003            421204    d
# 3              1.30             121003            507101    d
# 4              0.78             121003            263139    b
# ..              ...                ...               ...  ...
# 119            0.50             121003            342008    d
# 120            1.10             121003            342301    d
# 121            0.70             121003            492001    d
# 122            1.60             121003            517128    d
# 123            1.60             121003            173213    b
#
#             Type of Shipment  Billing Amount (Rs.)
# 0            Forward charges                 174.5
# 1            Forward charges                  90.2
# 2            Forward charges                  90.2
# 3            Forward charges                 140.0
# 4            Forward charges                  61.3
# ..                       ...                   ...
# 119          Forward charges                  45.4
# 120          Forward charges                 135.0
# 121  Forward and RTO charges                 172.8
# 122  Forward and RTO charges                 345.0
# 123          Forward charges                 117.9
#
# [124 rows x 11 columns]

# %% [markdown]
# **Create New Dataframe from newdf1 and uses column which is create by us and column customer pincode ,Type of Shipment,Warehouse Pincode**

# %%
newdf2=newdf1[['AWB Code','Order ID','Order Qty','Total Weight','Item Price(Per Qty.)','Customer Pincode','Type of Shipment',
               'Warehouse Pincode',]]

# %%
newdf2
# Out:
#           AWB Code    Order ID  Order Qty  Total Weight  Item Price(Per Qty.)  \
# 0    1091117221940  2001806210          2           220                  1324
# 1    1091117222065  2001806226          2           480                  1125
# 2    1091117222080  2001806229          3           500                  1082
# 3    1091117222124  2001806232          8          1302                  2139
# 4    1091117222135  2001806233          2           245                  1486
# ..             ...         ...        ...           ...                   ...
# 119  1091121183730  2001821995          2           477                   484
# 120  1091121305541  2001822466         10          1376                  9019
# 121  1091121666133  2001823564          6           672                  4803
# 122  1091121981575  2001825261         13          1557                  9049
# 123  1091122418320  2001827036         10          2176                  3640
#
#      Customer Pincode         Type of Shipment  Warehouse Pincode
# 0              140604          Forward charges             121003
# 1              723146          Forward charges             121003
# 2              421204          Forward charges             121003
# 3              507101          Forward charges             121003
# 4              263139          Forward charges             121003
# ..                ...                      ...                ...
# 119            342008          Forward charges             121003
# 120            342301          Forward charges             121003
# 121            492001  Forward and RTO charges             121003
# 122            517128  Forward and RTO charges             121003
# 123            173213          Forward charges             121003
#
# [124 rows x 8 columns]

# %%
pin
# Out:
#      Warehouse Pincode  Customer Pincode Zone
# 0               121003            507101    d
# 1               121003            486886    d
# 2               121003            532484    d
# 3               121003            143001    b
# 4               121003            515591    d
# ..                 ...               ...  ...
# 119             121003            325207    b
# 120             121003            303702    b
# 121             121003            313301    b
# 122             121003            173212    e
# 123             121003            302020    b
#
# [124 rows x 3 columns]

# %% [markdown]
# **Now we have to fetch the zone info from pin dataframe. So we create a dictionary from pin dataframe**

# %%
d=pin.set_index('Customer Pincode')['Zone'].to_dict()

# %%
d
# Out:
# {507101: 'd',
#  486886: 'd',
#  532484: 'd',
#  143001: 'b',
#  515591: 'd',
#  326502: 'd',
#  208019: 'b',
#  140301: 'b',
#  396001: 'd',
#  711106: 'd',
#  284001: 'b',
#  441601: 'd',
#  248006: 'b',
#  485001: 'd',
#  845438: 'd',
#  463106: 'd',
#  495671: 'd',
#  673002: 'e',
#  208002: 'b',
#  416010: 'd',
#  226010: 'b',
#  400705: 'd',
#  262405: 'b',
#  394210: 'd',
#  411014: 'd',
#  783301: 'e',
#  486661: 'd',
#  244001: 'b',
#  492001: 'd',
#  517128: 'd',
#  562110: 'd',
#  831006: 'd',
#  140604: 'b',
#  723146: 'd',
#  421204: 'd',
#  263139: 'b',
#  743263: 'd',
#  392150: 'd',
#  382830: 'd',
#  711303: 'd',
#  283102: 'b',
#  370201: 'd',
#  248001: 'b',
#  144001: 'b',
#  403401: 'd',
#  452001: 'd',
#  721636: 'd',
#  831002: 'd',
#  226004: 'b',
#  410206: 'd',
#  516503: 'd',
#  742103: 'd',
#  452018: 'd',
#  208001: 'b',
#  244713: 'b',
#  580007: 'd',
#  360005: 'd',
#  313027: 'b',
#  341001: 'b',
#  332715: 'b',
#  302031: 'b',
#  335001: 'b',
#  334004: 'b',
#  321001: 'b',
#  324001: 'b',
#  321608: 'b',
#  302002: 'b',
#  311011: 'b',
#  306302: 'b',
#  313001: 'b',
#  322255: 'b',
#  302017: 'b',
#  335512: 'b',
#  307026: 'b',
#  327025: 'b',
#  313333: 'b',
#  342008: 'b',
#  314401: 'b',
#  342301: 'b',
#  313003: 'b',
#  173212: 'e',
#  174101: 'e',
#  173213: 'e',
#  322201: 'b',
#  314001: 'b',
#  331022: 'b',
#  305801: 'b',
#  335502: 'b',
#  306116: 'b',
#  311001: 'b',
#  302019: 'b',
#  302039: 'b',
#  335803: 'b',
#  175101: 'e',
#  303903: 'b',
#  342012: 'b',
#  334001: 'b',
#  302012: 'b',
#  342014: 'b',
#  324005: 'b',
#  302001: 'b',
#  302004: 'b',
#  302018: 'b',
#  324008: 'b',
#  302020: 'b',
#  325207: 'b',
#  303702: 'b',
#  313301: 'b'}

# %% [markdown]
# **Mapping this dictionary to newdf2 dataframe and create new column 'Zone'**

# %%
newdf2['Zone']=newdf2['Customer Pincode'].map(d)

# %%
newdf2
# Out:
#           AWB Code    Order ID  Order Qty  Total Weight  Item Price(Per Qty.)  \
# 0    1091117221940  2001806210          2           220                  1324
# 1    1091117222065  2001806226          2           480                  1125
# 2    1091117222080  2001806229          3           500                  1082
# 3    1091117222124  2001806232          8          1302                  2139
# 4    1091117222135  2001806233          2           245                  1486
# ..             ...         ...        ...           ...                   ...
# 119  1091121183730  2001821995          2           477                   484
# 120  1091121305541  2001822466         10          1376                  9019
# 121  1091121666133  2001823564          6           672                  4803
# 122  1091121981575  2001825261         13          1557                  9049
# 123  1091122418320  2001827036         10          2176                  3640
#
#      Customer Pincode         Type of Shipment  Warehouse Pincode Zone
# 0              140604          Forward charges             121003    b
# 1              723146          Forward charges             121003    d
# 2              421204          Forward charges             121003    d
# 3              507101          Forward charges             121003    d
# 4              263139          Forward charges             121003    b
# ..                ...                      ...                ...  ...
# 119            342008          Forward charges             121003    b
# 120            342301          Forward charges             121003    b
# 121            492001  Forward and RTO charges             121003    d
# 122            517128  Forward and RTO charges             121003    d
# 123            173213          Forward charges             121003    e
#
# [124 rows x 9 columns]

# %% [markdown]
# **Calculate Applicable weight slab according to zone**

# %%
newdf2['Applicable weight slab(based on Zone)']=np.select([(newdf2['Zone']=='a'),(newdf2['Zone']=='b'),(newdf2['Zone']=='c'),
                                                           (newdf2['Zone']=='d'),(newdf2['Zone']=='e')
            ],[0.25,0.5,0.75,1.25,1.5])

# %%
newdf2
# Out:
#           AWB Code    Order ID  Order Qty  Total Weight  Item Price(Per Qty.)  \
# 0    1091117221940  2001806210          2           220                  1324
# 1    1091117222065  2001806226          2           480                  1125
# 2    1091117222080  2001806229          3           500                  1082
# 3    1091117222124  2001806232          8          1302                  2139
# 4    1091117222135  2001806233          2           245                  1486
# ..             ...         ...        ...           ...                   ...
# 119  1091121183730  2001821995          2           477                   484
# 120  1091121305541  2001822466         10          1376                  9019
# 121  1091121666133  2001823564          6           672                  4803
# 122  1091121981575  2001825261         13          1557                  9049
# 123  1091122418320  2001827036         10          2176                  3640
#
#      Customer Pincode         Type of Shipment  Warehouse Pincode Zone  \
# 0              140604          Forward charges             121003    b
# 1              723146          Forward charges             121003    d
# 2              421204          Forward charges             121003    d
# 3              507101          Forward charges             121003    d
# 4              263139          Forward charges             121003    b
# ..                ...                      ...                ...  ...
# 119            342008          Forward charges             121003    b
# 120            342301          Forward charges             121003    b
# 121            492001  Forward and RTO charges             121003    d
# 122            517128  Forward and RTO charges             121003    d
# 123            173213          Forward charges             121003    e
#
#      Applicable weight slab(based on Zone)
# 0                                     0.50
# 1                                     1.25
# 2                                     1.25
# 3                                     1.25
# 4                                     0.50
# ..                                     ...
# 119                                   0.50
# 120                                   0.50
# 121                                   1.25
# 122                                   1.25
# 123                                   1.50
#
# [124 rows x 10 columns]

# %%
newdf2['Total Weight']=newdf2['Total Weight']/1000

# %%
newdf2[newdf2['Zone']=='b']
# Out:
#           AWB Code    Order ID  Order Qty  Total Weight  Item Price(Per Qty.)  \
# 0    1091117221940  2001806210          2         0.220                  1324
# 4    1091117222135  2001806233          2         0.245                  1486
# 7    1091117222360  2001806304          3         0.500                  1082
# 11   1091117223244  2001806458          2         0.700                  1491
# 12   1091117223351  2001806471         10         1.621                  4243
# ..             ...         ...        ...           ...                   ...
# 116  1091121034114  2001821742          1         0.240                   603
# 117  1091121034350  2001821750          3         0.755                  1284
# 118  1091121034641  2001821766          2         0.240                   473
# 119  1091121183730  2001821995          2         0.477                   484
# 120  1091121305541  2001822466         10         1.376                  9019
#
#      Customer Pincode Type of Shipment  Warehouse Pincode Zone  \
# 0              140604  Forward charges             121003    b
# 4              263139  Forward charges             121003    b
# 7              302017  Forward charges             121003    b
# 11             143001  Forward charges             121003    b
# 12             313027  Forward charges             121003    b
# ..                ...              ...                ...  ...
# 116            327025  Forward charges             121003    b
# 117            313333  Forward charges             121003    b
# 118            313001  Forward charges             121003    b
# 119            342008  Forward charges             121003    b
# 120            342301  Forward charges             121003    b
#
#      Applicable weight slab(based on Zone)
# 0                                      0.5
# 4                                      0.5
# 7                                      0.5
# 11                                     0.5
# 12                                     0.5
# ..                                     ...
# 116                                    0.5
# 117                                    0.5
# 118                                    0.5
# 119                                    0.5
# 120                                    0.5
#
# [79 rows x 10 columns]

# %% [markdown]
# **Courier charges rate card at weight slab and pincode level. If the invoice mentions
# “Forward charges” then only forward charges (“fwd”) should be applicable as per zone
# and fixed & additional weights based on weight slabs. If the invoice mentions “Forward
# and rto charges” then forward charges (“fwd”) and RTO charges (“rto”) should be
# applicable as per zone and fixed & additional weights based on weight slabs.
# ● For the first slab of that zone, “fixed” rate as per the slab is applicable. For each
# additional slab, “additional” weight in the same proportion is applicable. Total charges will
# be “fixed” + “total additional” if any. For example: weight 2.2KG, Zone C. So for Zone C
# the slab length = 0.75KG. So the total applicable weight = 2.25KG. For the first 0.75 KG
# the charge is “fwd”, and for each 0.75 after the first, charges will be additional charges**

# %% [markdown]
# ***Create a function called newtestCondition for calculating Forwards charges etc***

# %%
def newtestCondition(s):
    c=math.ceil(s['Total Weight']/s['Applicable weight slab(based on Zone)'])
    counter=c+1
    charges=0
    i=1
    if((s['Zone']=='b') and (s['Type of Shipment']=='Forward charges')):
        
                
                while( i < counter):
                    if(i==1):
                        charges=33+charges
                        i=i+1
                        
                    else:
                        charges=28.3+charges
                        i=i+1
                return charges
    if((s['Zone']=='b') and (s['Type of Shipment']=='Forward and RTO charges')):
        
                
                while( i < counter):
                    if(i==1):
                        charges=33+20.5+charges
                        i=i+1
                        
                    else:
                        charges=28.3+28.3+charges
                        i=i+1
                return charges
    if((s['Zone']=='d') and (s['Type of Shipment']=='Forward charges')):
        
                
                while( i < counter):
                    if(i==1):
                        charges=45.4+charges
                        i=i+1
                        
                    else:
                        charges=44.8+charges
                        i=i+1
                return charges
    if((s['Zone']=='d') and (s['Type of Shipment']=='Forward and RTO charges')):
        
                
                while( i < counter):
                    if(i==1):
                        charges=45.4+41.3+charges
                        i=i+1
                        
                    else:
                        charges=44.8+44.8+charges
                        i=i+1
                return charges
    if((s['Zone']=='e') and (s['Type of Shipment']=='Forward charges')):
        
                
                while( i < counter):
                    if(i==1):
                        charges=56.6+charges
                        i=i+1
                        
                    else:
                        charges=55.5+charges
                        i=i+1
                return charges
    if((s['Zone']=='e') and (s['Type of Shipment']=='Forward and RTO charges')):
        
                
                while( i < counter):
                    if(i==1):
                        charges=56.6+50.7+charges
                        i=i+1
                        
                    else:
                        charges=55.5+55.5+charges
                        i=i+1
                return charges

# %% [markdown]
# ***Create new column ChargesSlap from function newtestCondition for forward charges***

# %%
newdf2['ChargesSlap']=newdf2.apply(newtestCondition,axis=1)

# %%
newdf2
# Out:
#           AWB Code    Order ID  Order Qty  Total Weight  Item Price(Per Qty.)  \
# 0    1091117221940  2001806210          2         0.220                  1324
# 1    1091117222065  2001806226          2         0.480                  1125
# 2    1091117222080  2001806229          3         0.500                  1082
# 3    1091117222124  2001806232          8         1.302                  2139
# 4    1091117222135  2001806233          2         0.245                  1486
# ..             ...         ...        ...           ...                   ...
# 119  1091121183730  2001821995          2         0.477                   484
# 120  1091121305541  2001822466         10         1.376                  9019
# 121  1091121666133  2001823564          6         0.672                  4803
# 122  1091121981575  2001825261         13         1.557                  9049
# 123  1091122418320  2001827036         10         2.176                  3640
#
#      Customer Pincode         Type of Shipment  Warehouse Pincode Zone  \
# 0              140604          Forward charges             121003    b
# 1              723146          Forward charges             121003    d
# 2              421204          Forward charges             121003    d
# 3              507101          Forward charges             121003    d
# 4              263139          Forward charges             121003    b
# ..                ...                      ...                ...  ...
# 119            342008          Forward charges             121003    b
# 120            342301          Forward charges             121003    b
# 121            492001  Forward and RTO charges             121003    d
# 122            517128  Forward and RTO charges             121003    d
# 123            173213          Forward charges             121003    e
#
#      Applicable weight slab(based on Zone)  ChargesSlap
# 0                                     0.50         33.0
# 1                                     1.25         45.4
# 2                                     1.25         45.4
# 3                                     1.25         90.2
# 4                                     0.50         33.0
# ..                                     ...          ...
# 119                                   0.50         33.0
# 120                                   0.50         89.6
# 121                                   1.25         86.7
# 122                                   1.25        176.3
# 123                                   1.50        112.1
#
# [124 rows x 11 columns]

# %% [markdown]
# **Now We use dictionary called din to map with newdf2 dataframe to create new column called Paymnet Mode**

# %%
din
# Out:
# {2001827036: 'COD',
#  2001825261: 'Prepaid',
#  2001823564: 'Prepaid',
#  2001822466: 'COD',
#  2001821995: 'Prepaid',
#  2001821766: 'COD',
#  2001821750: 'Prepaid',
#  2001821742: 'Prepaid',
#  2001821679: 'COD',
#  2001821502: 'Prepaid',
#  2001821284: 'COD',
#  2001821190: 'COD',
#  2001821185: 'COD',
#  2001820978: 'Prepaid',
#  2001820690: 'COD',
#  2001819252: 'Prepaid',
#  2001818390: 'COD',
#  2001817160: 'COD',
#  2001817093: 'COD',
#  2001816996: 'Prepaid',
#  2001816684: 'Prepaid',
#  2001816131: 'Prepaid',
#  2001815688: 'COD',
#  2001814580: 'COD',
#  2001813009: 'COD',
#  2001812941: 'COD',
#  2001812854: 'COD',
#  2001812838: 'COD',
#  2001812650: 'COD',
#  2001812195: 'Prepaid',
#  2001811809: 'Prepaid',
#  2001811604: 'COD',
#  2001811475: 'COD',
#  2001811466: 'Prepaid',
#  2001811363: 'Prepaid',
#  2001811306: 'Prepaid',
#  2001811305: 'COD',
#  2001811229: 'COD',
#  2001811192: 'Prepaid',
#  2001811153: 'Prepaid',
#  2001811058: 'Prepaid',
#  2001811039: 'Prepaid',
#  2001810697: 'COD',
#  2001810549: 'COD',
#  2001810281: 'COD',
#  2001810125: 'COD',
#  2001810104: 'COD',
#  2001809934: 'COD',
#  2001809917: 'COD',
#  2001809820: 'Prepaid',
#  2001809794: 'Prepaid',
#  2001809592: 'Prepaid',
#  2001809383: 'Prepaid',
#  2001809270: 'COD',
#  2001808992: 'COD',
#  2001808883: 'Prepaid',
#  2001808837: 'Prepaid',
#  2001808832: 'Prepaid',
#  2001808801: 'Prepaid',
#  2001808739: 'Prepaid',
#  2001808679: 'Prepaid',
#  2001808675: 'COD',
#  2001808585: 'COD',
#  2001808542: 'COD',
#  2001808507: 'Prepaid',
#  2001808475: 'Prepaid',
#  2001808295: 'COD',
#  2001808286: 'Prepaid',
#  2001808207: 'COD',
#  2001808118: 'Prepaid',
#  2001808102: 'Prepaid',
#  2001807981: 'COD',
#  2001807976: 'Prepaid',
#  2001807970: 'Prepaid',
#  2001807960: 'Prepaid',
#  2001807956: 'Prepaid',
#  2001807931: 'COD',
#  2001807930: 'Prepaid',
#  2001807852: 'Prepaid',
#  2001807814: 'Prepaid',
#  2001807785: 'Prepaid',
#  2001807613: 'COD',
#  2001807415: 'Prepaid',
#  2001807362: 'Prepaid',
#  2001807329: 'Prepaid',
#  2001807328: 'COD',
#  2001807290: 'Prepaid',
#  2001807241: 'Prepaid',
#  2001807186: 'Prepaid',
#  2001807084: 'COD',
#  2001807058: 'Prepaid',
#  2001807036: 'COD',
#  2001807012: 'Prepaid',
#  2001807004: 'Prepaid',
#  2001806968: 'Prepaid',
#  2001806885: 'COD',
#  2001806828: 'COD',
#  2001806823: 'COD',
#  2001806801: 'Prepaid',
#  2001806776: 'Prepaid',
#  2001806768: 'COD',
#  2001806735: 'Prepaid',
#  2001806733: 'Prepaid',
#  2001806726: 'COD',
#  2001806686: 'COD',
#  2001806652: 'COD',
#  2001806616: 'COD',
#  2001806575: 'COD',
#  2001806567: 'COD',
#  2001806547: 'COD',
#  2001806533: 'Prepaid',
#  2001806471: 'COD',
#  2001806458: 'Prepaid',
#  2001806446: 'Prepaid',
#  2001806408: 'Prepaid',
#  2001806338: 'Prepaid',
#  2001806304: 'Prepaid',
#  2001806273: 'COD',
#  2001806251: 'Prepaid',
#  2001806233: 'Prepaid',
#  2001806232: 'COD',
#  2001806229: 'COD',
#  2001806226: 'COD',
#  2001806210: 'COD'}

# %%
newdf2['Payment Mode']=newdf2['Order ID'].map(din)

# %%
newdf2
# Out:
#           AWB Code    Order ID  Order Qty  Total Weight  Item Price(Per Qty.)  \
# 0    1091117221940  2001806210          2         0.220                  1324
# 1    1091117222065  2001806226          2         0.480                  1125
# 2    1091117222080  2001806229          3         0.500                  1082
# 3    1091117222124  2001806232          8         1.302                  2139
# 4    1091117222135  2001806233          2         0.245                  1486
# ..             ...         ...        ...           ...                   ...
# 119  1091121183730  2001821995          2         0.477                   484
# 120  1091121305541  2001822466         10         1.376                  9019
# 121  1091121666133  2001823564          6         0.672                  4803
# 122  1091121981575  2001825261         13         1.557                  9049
# 123  1091122418320  2001827036         10         2.176                  3640
#
#      Customer Pincode         Type of Shipment  Warehouse Pincode Zone  \
# 0              140604          Forward charges             121003    b
# 1              723146          Forward charges             121003    d
# 2              421204          Forward charges             121003    d
# 3              507101          Forward charges             121003    d
# 4              263139          Forward charges             121003    b
# ..                ...                      ...                ...  ...
# 119            342008          Forward charges             121003    b
# 120            342301          Forward charges             121003    b
# 121            492001  Forward and RTO charges             121003    d
# 122            517128  Forward and RTO charges             121003    d
# 123            173213          Forward charges             121003    e
#
#      Applicable weight slab(based on Zone)  ChargesSlap Payment Mode
# 0                                     0.50         33.0          COD
# 1                                     1.25         45.4          COD
# 2                                     1.25         45.4          COD
# 3                                     1.25         90.2          COD
# 4                                     0.50         33.0      Prepaid
# ..                                     ...          ...          ...
# 119                                   0.50         33.0      Prepaid
# 120                                   0.50         89.6          COD
# 121                                   1.25         86.7      Prepaid
# 122                                   1.25        176.3      Prepaid
# 123                                   1.50        112.1          COD
#
# [124 rows x 12 columns]

# %% [markdown]
# **Calculate the COD charges. For this case, if the
# order is Prepaid then COD charge is 0 and if the order is COD then we need to check
# the amount of the order
# If the order amount is less than equal to 300 then COD charge is 15
# Else the COD charge is 5% of the Order Amount**

# %% [markdown]
# **Create Function called Condition1**

# %%
def condition1(s):
    if(s['Payment Mode']=='COD'):
        if(s['Item Price(Per Qty.)']<=300):
            return 15
        else:
            return s['Item Price(Per Qty.)']*0.05
    else:
        return 0

# %%
newdf2['COD']=newdf2.apply(condition1,axis=1)

# %%
newdf2
# Out:
#           AWB Code    Order ID  Order Qty  Total Weight  Item Price(Per Qty.)  \
# 0    1091117221940  2001806210          2         0.220                  1324
# 1    1091117222065  2001806226          2         0.480                  1125
# 2    1091117222080  2001806229          3         0.500                  1082
# 3    1091117222124  2001806232          8         1.302                  2139
# 4    1091117222135  2001806233          2         0.245                  1486
# ..             ...         ...        ...           ...                   ...
# 119  1091121183730  2001821995          2         0.477                   484
# 120  1091121305541  2001822466         10         1.376                  9019
# 121  1091121666133  2001823564          6         0.672                  4803
# 122  1091121981575  2001825261         13         1.557                  9049
# 123  1091122418320  2001827036         10         2.176                  3640
#
#      Customer Pincode         Type of Shipment  Warehouse Pincode Zone  \
# 0              140604          Forward charges             121003    b
# 1              723146          Forward charges             121003    d
# 2              421204          Forward charges             121003    d
# 3              507101          Forward charges             121003    d
# 4              263139          Forward charges             121003    b
# ..                ...                      ...                ...  ...
# 119            342008          Forward charges             121003    b
# 120            342301          Forward charges             121003    b
# 121            492001  Forward and RTO charges             121003    d
# 122            517128  Forward and RTO charges             121003    d
# 123            173213          Forward charges             121003    e
#
#      Applicable weight slab(based on Zone)  ChargesSlap Payment Mode     COD
# 0                                     0.50         33.0          COD   66.20
# 1                                     1.25         45.4          COD   56.25
# 2                                     1.25         45.4          COD   54.10
# 3                                     1.25         90.2          COD  106.95
# 4                                     0.50         33.0      Prepaid    0.00
# ..                                     ...          ...          ...     ...
# 119                                   0.50         33.0      Prepaid    0.00
# 120                                   0.50         89.6          COD  450.95
# 121                                   1.25         86.7      Prepaid    0.00
# 122                                   1.25        176.3      Prepaid    0.00
# 123                                   1.50        112.1          COD  182.00
#
# [124 rows x 13 columns]

# %% [markdown]
# ***Calculating total charges by Company X***

# %%
newdf2['Total Charges']=newdf2['COD']+newdf2['ChargesSlap']

# %%
newdf2
# Out:
#           AWB Code    Order ID  Order Qty  Total Weight  Item Price(Per Qty.)  \
# 0    1091117221940  2001806210          2         0.220                  1324
# 1    1091117222065  2001806226          2         0.480                  1125
# 2    1091117222080  2001806229          3         0.500                  1082
# 3    1091117222124  2001806232          8         1.302                  2139
# 4    1091117222135  2001806233          2         0.245                  1486
# ..             ...         ...        ...           ...                   ...
# 119  1091121183730  2001821995          2         0.477                   484
# 120  1091121305541  2001822466         10         1.376                  9019
# 121  1091121666133  2001823564          6         0.672                  4803
# 122  1091121981575  2001825261         13         1.557                  9049
# 123  1091122418320  2001827036         10         2.176                  3640
#
#      Customer Pincode         Type of Shipment  Warehouse Pincode Zone  \
# 0              140604          Forward charges             121003    b
# 1              723146          Forward charges             121003    d
# 2              421204          Forward charges             121003    d
# 3              507101          Forward charges             121003    d
# 4              263139          Forward charges             121003    b
# ..                ...                      ...                ...  ...
# 119            342008          Forward charges             121003    b
# 120            342301          Forward charges             121003    b
# 121            492001  Forward and RTO charges             121003    d
# 122            517128  Forward and RTO charges             121003    d
# 123            173213          Forward charges             121003    e
#
#      Applicable weight slab(based on Zone)  ChargesSlap Payment Mode     COD  \
# 0                                     0.50         33.0          COD   66.20
# 1                                     1.25         45.4          COD   56.25
# 2                                     1.25         45.4          COD   54.10
# 3                                     1.25         90.2          COD  106.95
# 4                                     0.50         33.0      Prepaid    0.00
# ..                                     ...          ...          ...     ...
# 119                                   0.50         33.0      Prepaid    0.00
# 120                                   0.50         89.6          COD  450.95
# 121                                   1.25         86.7      Prepaid    0.00
# 122                                   1.25        176.3      Prepaid    0.00
# 123                                   1.50        112.1          COD  182.00
#
#      Total Charges
# 0            99.20
# 1           101.65
# 2            99.50
# 3           197.15
# 4            33.00
# ..             ...
# 119          33.00
# 120         540.55
# 121          86.70
# 122         176.30
# 123         294.10
#
# [124 rows x 14 columns]

# %%
t=newdf2

# %%
cour3=cour[['Order ID','Billing Amount (Rs.)']]

# %%
cour3
# Out:
#        Order ID  Billing Amount (Rs.)
# 0    2001806232                 140.0
# 1    2001806273                 101.2
# 2    2001806408                 224.6
# 3    2001806458                  61.3
# 4    2001807012                  45.4
# ..          ...                   ...
# 119  2001812941                  95.2
# 120  2001809383                  86.7
# 121  2001820978                  45.4
# 122  2001811475                  47.0
# 123  2001811305                  65.4
#
# [124 rows x 2 columns]

# %%
tt=pd.merge(left=t,right=cour3,on='Order ID')

# %%
tt
# Out:
#           AWB Code    Order ID  Order Qty  Total Weight  Item Price(Per Qty.)  \
# 0    1091117221940  2001806210          2         0.220                  1324
# 1    1091117222065  2001806226          2         0.480                  1125
# 2    1091117222080  2001806229          3         0.500                  1082
# 3    1091117222124  2001806232          8         1.302                  2139
# 4    1091117222135  2001806233          2         0.245                  1486
# ..             ...         ...        ...           ...                   ...
# 119  1091121183730  2001821995          2         0.477                   484
# 120  1091121305541  2001822466         10         1.376                  9019
# 121  1091121666133  2001823564          6         0.672                  4803
# 122  1091121981575  2001825261         13         1.557                  9049
# 123  1091122418320  2001827036         10         2.176                  3640
#
#      Customer Pincode         Type of Shipment  Warehouse Pincode Zone  \
# 0              140604          Forward charges             121003    b
# 1              723146          Forward charges             121003    d
# 2              421204          Forward charges             121003    d
# 3              507101          Forward charges             121003    d
# 4              263139          Forward charges             121003    b
# ..                ...                      ...                ...  ...
# 119            342008          Forward charges             121003    b
# 120            342301          Forward charges             121003    b
# 121            492001  Forward and RTO charges             121003    d
# 122            517128  Forward and RTO charges             121003    d
# 123            173213          Forward charges             121003    e
#
#      Applicable weight slab(based on Zone)  ChargesSlap Payment Mode     COD  \
# 0                                     0.50         33.0          COD   66.20
# 1                                     1.25         45.4          COD   56.25
# 2                                     1.25         45.4          COD   54.10
# 3                                     1.25         90.2          COD  106.95
# 4                                     0.50         33.0      Prepaid    0.00
# ..                                     ...          ...          ...     ...
# 119                                   0.50         33.0      Prepaid    0.00
# 120                                   0.50         89.6          COD  450.95
# 121                                   1.25         86.7      Prepaid    0.00
# 122                                   1.25        176.3      Prepaid    0.00
# 123                                   1.50        112.1          COD  182.00
#
#      Total Charges  Billing Amount (Rs.)
# 0            99.20                 174.5
# 1           101.65                  90.2
# 2            99.50                  90.2
# 3           197.15                 140.0
# 4            33.00                  61.3
# ..             ...                   ...
# 119          33.00                  45.4
# 120         540.55                 135.0
# 121          86.70                 172.8
# 122         176.30                 345.0
# 123         294.10                 117.9
#
# [124 rows x 15 columns]

# %% [markdown]
# **Create new column for calcuating Difference Between Expected Charges and Billed Charges (Rs.)**

# %%
tt['Difference Between Expected Charges and Billed Charges (Rs.)']=tt['Total Charges']-tt['Billing Amount (Rs.)']

# %%
math.ceil(1.376/0.50)
# Out:
# 3

# %% [markdown]
# **Function called weightSlapX is create to calculate weight slap by Company X**

# %%
def weightSlapX(s):
    c=math.ceil(s['Total Weight']/s['Applicable weight slab(based on Zone)'])
    return c

# %% [markdown]
# **New column is create by using function weightSlapX**

# %%
tt['WeightslabX']=tt.apply(weightSlapX,axis=1)

# %% [markdown]
# **Renaming Column**

# %%
tt.rename(columns={'Total Weight':'TotalweightasperX(kg)','Zone':'DeliveryZoneasperX','Total Charges':'ExpectedChargeasperX(Rs.)','Billing Amount (Rs.)':'Charges Billed by Courier Company (Rs.)'},inplace=True)

# %%
tt
# Out:
#           AWB Code    Order ID  Order Qty  TotalweightasperX(kg)  \
# 0    1091117221940  2001806210          2                  0.220
# 1    1091117222065  2001806226          2                  0.480
# 2    1091117222080  2001806229          3                  0.500
# 3    1091117222124  2001806232          8                  1.302
# 4    1091117222135  2001806233          2                  0.245
# ..             ...         ...        ...                    ...
# 119  1091121183730  2001821995          2                  0.477
# 120  1091121305541  2001822466         10                  1.376
# 121  1091121666133  2001823564          6                  0.672
# 122  1091121981575  2001825261         13                  1.557
# 123  1091122418320  2001827036         10                  2.176
#
#      Item Price(Per Qty.)  Customer Pincode         Type of Shipment  \
# 0                    1324            140604          Forward charges
# 1                    1125            723146          Forward charges
# 2                    1082            421204          Forward charges
# 3                    2139            507101          Forward charges
# 4                    1486            263139          Forward charges
# ..                    ...               ...                      ...
# 119                   484            342008          Forward charges
# 120                  9019            342301          Forward charges
# 121                  4803            492001  Forward and RTO charges
# 122                  9049            517128  Forward and RTO charges
# 123                  3640            173213          Forward charges
#
#      Warehouse Pincode DeliveryZoneasperX  \
# 0               121003                  b
# 1               121003                  d
# 2               121003                  d
# 3               121003                  d
# 4               121003                  b
# ..                 ...                ...
# 119             121003                  b
# 120             121003                  b
# 121             121003                  d
# 122             121003                  d
# 123             121003                  e
#
#      Applicable weight slab(based on Zone)  ChargesSlap Payment Mode     COD  \
# 0                                     0.50         33.0          COD   66.20
# 1                                     1.25         45.4          COD   56.25
# 2                                     1.25         45.4          COD   54.10
# 3                                     1.25         90.2          COD  106.95
# 4                                     0.50         33.0      Prepaid    0.00
# ..                                     ...          ...          ...     ...
# 119                                   0.50         33.0      Prepaid    0.00
# 120                                   0.50         89.6          COD  450.95
# 121                                   1.25         86.7      Prepaid    0.00
# 122                                   1.25        176.3      Prepaid    0.00
# 123                                   1.50        112.1          COD  182.00
#
#      ExpectedChargeasperX(Rs.)  Charges Billed by Courier Company (Rs.)  \
# 0                        99.20                                    174.5
# 1                       101.65                                     90.2
# 2                        99.50                                     90.2
# 3                       197.15                                    140.0
# 4                        33.00                                     61.3
# ..                         ...                                      ...
# 119                      33.00                                     45.4
# 120                     540.55                                    135.0
# 121                      86.70                                    172.8
# 122                     176.30                                    345.0
# 123                     294.10                                    117.9
#
#      Difference Between Expected Charges and Billed Charges (Rs.)  WeightslabX
# 0                                               -75.30                       1
# 1                                                11.45                       1
# 2                                                 9.30                       1
# 3                                                57.15                       2
# 4                                               -28.30                       1
# ..                                                 ...                     ...
# 119                                             -12.40                       1
# 120                                             405.55                       3
# 121                                             -86.10                       1
# 122                                            -168.70                       2
# 123                                             176.20                       2
#
# [124 rows x 17 columns]

# %% [markdown]
# **Create new dataframe from tt dataframe by selecting columns required for Report**

# %%
finalt=tt[['Order ID','AWB Code','TotalweightasperX(kg)','WeightslabX','DeliveryZoneasperX','ExpectedChargeasperX(Rs.)',
           'Charges Billed by Courier Company (Rs.)','Difference Between Expected Charges and Billed Charges (Rs.)'
           ]]

# %% [markdown]
# **Now using courier company file**

# %%
cour
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 140.0
# 1              486886    d          Forward charges                 101.2
# 2              532484    d          Forward charges                 224.6
# 3              143001    b          Forward charges                  61.3
# 4              515591    d          Forward charges                  45.4
# ..                ...  ...                      ...                   ...
# 119            325207    d          Forward charges                  95.2
# 120            303702    d  Forward and RTO charges                  86.7
# 121            313301    d          Forward charges                  45.4
# 122            173212    b          Forward charges                  47.0
# 123            302020    d          Forward charges                  65.4
#
# [124 rows x 8 columns]

# %%
courtest=cour

# %%
courtest
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 140.0
# 1              486886    d          Forward charges                 101.2
# 2              532484    d          Forward charges                 224.6
# 3              143001    b          Forward charges                  61.3
# 4              515591    d          Forward charges                  45.4
# ..                ...  ...                      ...                   ...
# 119            325207    d          Forward charges                  95.2
# 120            303702    d  Forward and RTO charges                  86.7
# 121            313301    d          Forward charges                  45.4
# 122            173212    b          Forward charges                  47.0
# 123            302020    d          Forward charges                  65.4
#
# [124 rows x 8 columns]

# %% [markdown]
# **Getting weight slab by Courier Company**

# %%
courtest['Weight slab by Courier']=np.select([(newdf2['Zone']=='a'),(newdf2['Zone']=='b'),(newdf2['Zone']=='c'),
                                                           (newdf2['Zone']=='d'),(newdf2['Zone']=='e')
            ],[0.25,0.5,0.75,1.25,1.5])

# %%
courtest
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)  \
# 0              507101    d          Forward charges                 140.0
# 1              486886    d          Forward charges                 101.2
# 2              532484    d          Forward charges                 224.6
# 3              143001    b          Forward charges                  61.3
# 4              515591    d          Forward charges                  45.4
# ..                ...  ...                      ...                   ...
# 119            325207    d          Forward charges                  95.2
# 120            303702    d  Forward and RTO charges                  86.7
# 121            313301    d          Forward charges                  45.4
# 122            173212    b          Forward charges                  47.0
# 123            302020    d          Forward charges                  65.4
#
#      Weight slab by Courier
# 0                      0.50
# 1                      1.25
# 2                      1.25
# 3                      1.25
# 4                      0.50
# ..                      ...
# 119                    0.50
# 120                    0.50
# 121                    1.25
# 122                    1.25
# 123                    1.50
#
# [124 rows x 9 columns]

# %%
def weightSlapX2(s):
    c=math.ceil(s['Charged Weight']/s['Weight slab by Courier'])
    return c

# %%
courtest['Weight slab charged by Courier Company (KG)']=courtest.apply(weightSlapX2,axis=1)

# %% [markdown]
# **Renaming some column of courtest file for report**

# %%
courtest.rename(columns={'Charged Weight':'Total weight as per Courier Company (KG)','Zone':'Delivery Zone charged by Courier Company'},inplace=True)

# %%
courtest1=courtest[['Order ID','Total weight as per Courier Company (KG)','Weight slab charged by Courier Company (KG)','Delivery Zone charged by Courier Company']]

# %%
courtest1
# Out:
#        Order ID  Total weight as per Courier Company (KG)  \
# 0    2001806232                                      1.30
# 1    2001806273                                      1.00
# 2    2001806408                                      2.50
# 3    2001806458                                      1.00
# 4    2001807012                                      0.15
# ..          ...                                       ...
# 119  2001812941                                      0.73
# 120  2001809383                                      0.50
# 121  2001820978                                      0.50
# 122  2001811475                                      0.50
# 123  2001811305                                      0.50
#
#      Weight slab charged by Courier Company (KG)  \
# 0                                              3
# 1                                              1
# 2                                              2
# 3                                              1
# 4                                              1
# ..                                           ...
# 119                                            2
# 120                                            1
# 121                                            1
# 122                                            1
# 123                                            1
#
#     Delivery Zone charged by Courier Company
# 0                                          d
# 1                                          d
# 2                                          d
# 3                                          b
# 4                                          d
# ..                                       ...
# 119                                        d
# 120                                        d
# 121                                        d
# 122                                        b
# 123                                        d
#
# [124 rows x 4 columns]

# %%
final=pd.merge(left=finalt,right=courtest1,on='Order ID')

# %%
final
# Out:
#        Order ID       AWB Code  TotalweightasperX(kg)  WeightslabX  \
# 0    2001806210  1091117221940                  0.220            1
# 1    2001806226  1091117222065                  0.480            1
# 2    2001806229  1091117222080                  0.500            1
# 3    2001806232  1091117222124                  1.302            2
# 4    2001806233  1091117222135                  0.245            1
# ..          ...            ...                    ...          ...
# 119  2001821995  1091121183730                  0.477            1
# 120  2001822466  1091121305541                  1.376            3
# 121  2001823564  1091121666133                  0.672            1
# 122  2001825261  1091121981575                  1.557            2
# 123  2001827036  1091122418320                  2.176            2
#
#     DeliveryZoneasperX  ExpectedChargeasperX(Rs.)  \
# 0                    b                      99.20
# 1                    d                     101.65
# 2                    d                      99.50
# 3                    d                     197.15
# 4                    b                      33.00
# ..                 ...                        ...
# 119                  b                      33.00
# 120                  b                     540.55
# 121                  d                      86.70
# 122                  d                     176.30
# 123                  e                     294.10
#
#      Charges Billed by Courier Company (Rs.)  \
# 0                                      174.5
# 1                                       90.2
# 2                                       90.2
# 3                                      140.0
# 4                                       61.3
# ..                                       ...
# 119                                     45.4
# 120                                    135.0
# 121                                    172.8
# 122                                    345.0
# 123                                    117.9
#
#      Difference Between Expected Charges and Billed Charges (Rs.)  \
# 0                                               -75.30
# 1                                                11.45
# 2                                                 9.30
# 3                                                57.15
# 4                                               -28.30
# ..                                                 ...
# 119                                             -12.40
# 120                                             405.55
# 121                                             -86.10
# 122                                            -168.70
# 123                                             176.20
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 1                                        0.68
# 2                                        0.71
# 3                                        1.30
# 4                                        0.78
# ..                                        ...
# 119                                      0.50
# 120                                      1.10
# 121                                      0.70
# 122                                      1.60
# 123                                      1.60
#
#      Weight slab charged by Courier Company (KG)  \
# 0                                              6
# 1                                              1
# 2                                              1
# 3                                              3
# 4                                              2
# ..                                           ...
# 119                                            1
# 120                                            1
# 121                                            2
# 122                                            2
# 123                                            4
#
#     Delivery Zone charged by Courier Company
# 0                                          b
# 1                                          d
# 2                                          d
# 3                                          d
# 4                                          b
# ..                                       ...
# 119                                        d
# 120                                        d
# 121                                        d
# 122                                        d
# 123                                        b
#
# [124 rows x 11 columns]

# %%
final=final[['Order ID','AWB Code','TotalweightasperX(kg)','WeightslabX','Total weight as per Courier Company (KG)','Weight slab charged by Courier Company (KG)','DeliveryZoneasperX','Delivery Zone charged by Courier Company','ExpectedChargeasperX(Rs.)',
           'Charges Billed by Courier Company (Rs.)','Difference Between Expected Charges and Billed Charges (Rs.)'
           ]]

# %%
final
# Out:
#        Order ID       AWB Code  TotalweightasperX(kg)  WeightslabX  \
# 0    2001806210  1091117221940                  0.220            1
# 1    2001806226  1091117222065                  0.480            1
# 2    2001806229  1091117222080                  0.500            1
# 3    2001806232  1091117222124                  1.302            2
# 4    2001806233  1091117222135                  0.245            1
# ..          ...            ...                    ...          ...
# 119  2001821995  1091121183730                  0.477            1
# 120  2001822466  1091121305541                  1.376            3
# 121  2001823564  1091121666133                  0.672            1
# 122  2001825261  1091121981575                  1.557            2
# 123  2001827036  1091122418320                  2.176            2
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 1                                        0.68
# 2                                        0.71
# 3                                        1.30
# 4                                        0.78
# ..                                        ...
# 119                                      0.50
# 120                                      1.10
# 121                                      0.70
# 122                                      1.60
# 123                                      1.60
#
#      Weight slab charged by Courier Company (KG) DeliveryZoneasperX  \
# 0                                              6                  b
# 1                                              1                  d
# 2                                              1                  d
# 3                                              3                  d
# 4                                              2                  b
# ..                                           ...                ...
# 119                                            1                  b
# 120                                            1                  b
# 121                                            2                  d
# 122                                            2                  d
# 123                                            4                  e
#
#     Delivery Zone charged by Courier Company  ExpectedChargeasperX(Rs.)  \
# 0                                          b                      99.20
# 1                                          d                     101.65
# 2                                          d                      99.50
# 3                                          d                     197.15
# 4                                          b                      33.00
# ..                                       ...                        ...
# 119                                        d                      33.00
# 120                                        d                     540.55
# 121                                        d                      86.70
# 122                                        d                     176.30
# 123                                        b                     294.10
#
#      Charges Billed by Courier Company (Rs.)  \
# 0                                      174.5
# 1                                       90.2
# 2                                       90.2
# 3                                      140.0
# 4                                       61.3
# ..                                       ...
# 119                                     45.4
# 120                                    135.0
# 121                                    172.8
# 122                                    345.0
# 123                                    117.9
#
#      Difference Between Expected Charges and Billed Charges (Rs.)
# 0                                               -75.30
# 1                                                11.45
# 2                                                 9.30
# 3                                                57.15
# 4                                               -28.30
# ..                                                 ...
# 119                                             -12.40
# 120                                             405.55
# 121                                             -86.10
# 122                                            -168.70
# 123                                             176.20
#
# [124 rows x 11 columns]

# %%
f=final

# %%
f
# Out:
#        Order ID       AWB Code  TotalweightasperX(kg)  WeightslabX  \
# 0    2001806210  1091117221940                  0.220            1
# 1    2001806226  1091117222065                  0.480            1
# 2    2001806229  1091117222080                  0.500            1
# 3    2001806232  1091117222124                  1.302            2
# 4    2001806233  1091117222135                  0.245            1
# ..          ...            ...                    ...          ...
# 119  2001821995  1091121183730                  0.477            1
# 120  2001822466  1091121305541                  1.376            3
# 121  2001823564  1091121666133                  0.672            1
# 122  2001825261  1091121981575                  1.557            2
# 123  2001827036  1091122418320                  2.176            2
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 1                                        0.68
# 2                                        0.71
# 3                                        1.30
# 4                                        0.78
# ..                                        ...
# 119                                      0.50
# 120                                      1.10
# 121                                      0.70
# 122                                      1.60
# 123                                      1.60
#
#      Weight slab charged by Courier Company (KG) DeliveryZoneasperX  \
# 0                                              6                  b
# 1                                              1                  d
# 2                                              1                  d
# 3                                              3                  d
# 4                                              2                  b
# ..                                           ...                ...
# 119                                            1                  b
# 120                                            1                  b
# 121                                            2                  d
# 122                                            2                  d
# 123                                            4                  e
#
#     Delivery Zone charged by Courier Company  ExpectedChargeasperX(Rs.)  \
# 0                                          b                      99.20
# 1                                          d                     101.65
# 2                                          d                      99.50
# 3                                          d                     197.15
# 4                                          b                      33.00
# ..                                       ...                        ...
# 119                                        d                      33.00
# 120                                        d                     540.55
# 121                                        d                      86.70
# 122                                        d                     176.30
# 123                                        b                     294.10
#
#      Charges Billed by Courier Company (Rs.)  \
# 0                                      174.5
# 1                                       90.2
# 2                                       90.2
# 3                                      140.0
# 4                                       61.3
# ..                                       ...
# 119                                     45.4
# 120                                    135.0
# 121                                    172.8
# 122                                    345.0
# 123                                    117.9
#
#      Difference Between Expected Charges and Billed Charges (Rs.)
# 0                                               -75.30
# 1                                                11.45
# 2                                                 9.30
# 3                                                57.15
# 4                                               -28.30
# ..                                                 ...
# 119                                             -12.40
# 120                                             405.55
# 121                                             -86.10
# 122                                            -168.70
# 123                                             176.20
#
# [124 rows x 11 columns]

# %% [markdown]
# **Calculating Correctly Charge, Overcharge, UnderCharge of Company X**

# %%
Correctly_Charges=f[f['ExpectedChargeasperX(Rs.)']==f['Charges Billed by Courier Company (Rs.)']]

# %%
Correctly_Charges
# Out:
#       Order ID       AWB Code  TotalweightasperX(kg)  WeightslabX  \
# 11  2001806458  1091117223244                  0.700            2
# 31  2001807012  1091117229345                  0.240            1
# 33  2001807058  1091117323112                  1.168            3
# 35  2001807186  1091117323812                  0.500            1
# 37  2001807290  1091117324206                  0.500            1
# 44  2001807814  1091117326612                  0.607            2
# 46  2001807930  1091117327695                  0.240            1
# 48  2001807956  1091117327275                  1.080            3
# 54  2001808118  1091117435134                  0.343            1
# 59  2001808507  1091117436383                  0.607            2
#
#     Total weight as per Courier Company (KG)  \
# 11                                      1.00
# 31                                      0.15
# 33                                      1.15
# 35                                      0.50
# 37                                      0.50
# 44                                      0.79
# 46                                      0.15
# 48                                      1.08
# 54                                      0.50
# 59                                      0.79
#
#     Weight slab charged by Courier Company (KG) DeliveryZoneasperX  \
# 11                                            1                  b
# 31                                            1                  d
# 33                                            3                  b
# 35                                            1                  d
# 37                                            1                  d
# 44                                            1                  b
# 46                                            1                  d
# 48                                            3                  b
# 54                                            1                  b
# 59                                            1                  b
#
#    Delivery Zone charged by Courier Company  ExpectedChargeasperX(Rs.)  \
# 11                                        b                       61.3
# 31                                        d                       45.4
# 33                                        b                       89.6
# 35                                        d                       45.4
# 37                                        d                       45.4
# 44                                        b                       61.3
# 46                                        d                       45.4
# 48                                        b                       89.6
# 54                                        b                       33.0
# 59                                        b                       61.3
#
#     Charges Billed by Courier Company (Rs.)  \
# 11                                     61.3
# 31                                     45.4
# 33                                     89.6
# 35                                     45.4
# 37                                     45.4
# 44                                     61.3
# 46                                     45.4
# 48                                     89.6
# 54                                     33.0
# 59                                     61.3
#
#     Difference Between Expected Charges and Billed Charges (Rs.)
# 11                                                0.0
# 31                                                0.0
# 33                                                0.0
# 35                                                0.0
# 37                                                0.0
# 44                                                0.0
# 46                                                0.0
# 48                                                0.0
# 54                                                0.0
# 59                                                0.0

# %%
Correctly_Charges_Count=len(Correctly_Charges.index)

# %%
Correctly_Charges_Sum=Correctly_Charges['ExpectedChargeasperX(Rs.)'].sum()

# %%
Correctly_Charges_Count
# Out:
# 10

# %%
Correctly_Charges_Sum
# Out:
# 577.6999999999999

# %%
Overcharge=f[f['ExpectedChargeasperX(Rs.)']<f['Charges Billed by Courier Company (Rs.)']]

# %%
Overcharge
# Out:
#        Order ID       AWB Code  TotalweightasperX(kg)  WeightslabX  \
# 0    2001806210  1091117221940                  0.220            1
# 4    2001806233  1091117222135                  0.245            1
# 5    2001806251  1091117222146                  0.245            1
# 7    2001806304  1091117222360                  0.500            1
# 8    2001806338  1091117222570                  0.500            1
# ..          ...            ...                    ...          ...
# 117  2001821750  1091121034350                  0.755            2
# 118  2001821766  1091121034641                  0.240            1
# 119  2001821995  1091121183730                  0.477            1
# 121  2001823564  1091121666133                  0.672            1
# 122  2001825261  1091121981575                  1.557            2
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 4                                        0.78
# 5                                        1.27
# 7                                        0.71
# 8                                        0.70
# ..                                        ...
# 117                                      0.80
# 118                                      0.20
# 119                                      0.50
# 121                                      0.70
# 122                                      1.60
#
#      Weight slab charged by Courier Company (KG) DeliveryZoneasperX  \
# 0                                              6                  b
# 4                                              2                  b
# 5                                              2                  d
# 7                                              2                  b
# 8                                              2                  d
# ..                                           ...                ...
# 117                                            2                  b
# 118                                            1                  b
# 119                                            1                  b
# 121                                            2                  d
# 122                                            2                  d
#
#     Delivery Zone charged by Courier Company  ExpectedChargeasperX(Rs.)  \
# 0                                          b                      99.20
# 4                                          b                      33.00
# 5                                          d                      45.40
# 7                                          d                      33.00
# 8                                          d                      45.40
# ..                                       ...                        ...
# 117                                        d                      61.30
# 118                                        d                      56.65
# 119                                        d                      33.00
# 121                                        d                      86.70
# 122                                        d                     176.30
#
#      Charges Billed by Courier Company (Rs.)  \
# 0                                      174.5
# 4                                       61.3
# 5                                      135.0
# 7                                       90.2
# 8                                       90.2
# ..                                       ...
# 117                                     90.2
# 118                                     63.4
# 119                                     45.4
# 121                                    172.8
# 122                                    345.0
#
#      Difference Between Expected Charges and Billed Charges (Rs.)
# 0                                               -75.30
# 4                                               -28.30
# 5                                               -89.60
# 7                                               -57.20
# 8                                               -44.80
# ..                                                 ...
# 117                                             -28.90
# 118                                              -6.75
# 119                                             -12.40
# 121                                             -86.10
# 122                                            -168.70
#
# [70 rows x 11 columns]

# %%
Overcharge['Difference Between Expected Charges and Billed Charges (Rs.)']=Overcharge['Difference Between Expected Charges and Billed Charges (Rs.)'].abs()

# %%
Overcharge
# Out:
#        Order ID       AWB Code  TotalweightasperX(kg)  WeightslabX  \
# 0    2001806210  1091117221940                  0.220            1
# 4    2001806233  1091117222135                  0.245            1
# 5    2001806251  1091117222146                  0.245            1
# 7    2001806304  1091117222360                  0.500            1
# 8    2001806338  1091117222570                  0.500            1
# ..          ...            ...                    ...          ...
# 117  2001821750  1091121034350                  0.755            2
# 118  2001821766  1091121034641                  0.240            1
# 119  2001821995  1091121183730                  0.477            1
# 121  2001823564  1091121666133                  0.672            1
# 122  2001825261  1091121981575                  1.557            2
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 4                                        0.78
# 5                                        1.27
# 7                                        0.71
# 8                                        0.70
# ..                                        ...
# 117                                      0.80
# 118                                      0.20
# 119                                      0.50
# 121                                      0.70
# 122                                      1.60
#
#      Weight slab charged by Courier Company (KG) DeliveryZoneasperX  \
# 0                                              6                  b
# 4                                              2                  b
# 5                                              2                  d
# 7                                              2                  b
# 8                                              2                  d
# ..                                           ...                ...
# 117                                            2                  b
# 118                                            1                  b
# 119                                            1                  b
# 121                                            2                  d
# 122                                            2                  d
#
#     Delivery Zone charged by Courier Company  ExpectedChargeasperX(Rs.)  \
# 0                                          b                      99.20
# 4                                          b                      33.00
# 5                                          d                      45.40
# 7                                          d                      33.00
# 8                                          d                      45.40
# ..                                       ...                        ...
# 117                                        d                      61.30
# 118                                        d                      56.65
# 119                                        d                      33.00
# 121                                        d                      86.70
# 122                                        d                     176.30
#
#      Charges Billed by Courier Company (Rs.)  \
# 0                                      174.5
# 4                                       61.3
# 5                                      135.0
# 7                                       90.2
# 8                                       90.2
# ..                                       ...
# 117                                     90.2
# 118                                     63.4
# 119                                     45.4
# 121                                    172.8
# 122                                    345.0
#
#      Difference Between Expected Charges and Billed Charges (Rs.)
# 0                                                75.30
# 4                                                28.30
# 5                                                89.60
# 7                                                57.20
# 8                                                44.80
# ..                                                 ...
# 117                                              28.90
# 118                                               6.75
# 119                                              12.40
# 121                                              86.10
# 122                                             168.70
#
# [70 rows x 11 columns]

# %%
Overcharge_Count=len(Overcharge.index)

# %%
Overcharge_Count
# Out:
# 70

# %%
Overcharge_Sum=Overcharge['Difference Between Expected Charges and Billed Charges (Rs.)'].sum()

# %%
Overcharge_Sum
# Out:
# 4178.700000000001

# %%
Undercharge=f[f['ExpectedChargeasperX(Rs.)']>f['Charges Billed by Courier Company (Rs.)']]

# %%
Undercharge
# Out:
#        Order ID       AWB Code  TotalweightasperX(kg)  WeightslabX  \
# 1    2001806226  1091117222065                  0.480            1
# 2    2001806229  1091117222080                  0.500            1
# 3    2001806232  1091117222124                  1.302            2
# 6    2001806273  1091117222194                  0.615            1
# 12   2001806471  1091117223351                  1.621            4
# 15   2001806567  1091117224902                  0.952            1
# 16   2001806575  1091117225016                  0.500            1
# 17   2001806616  1091117225484                  0.963            2
# 18   2001806652  1091117226221                  0.500            1
# 19   2001806686  1091117229555                  0.240            1
# 20   2001806726  1091117226910                  0.500            1
# 23   2001806768  1091117227116                  0.840            2
# 28   2001806885  1091117229776                  0.840            2
# 32   2001807036  1091117323005                  1.459            2
# 41   2001807415  1091117325094                  1.048            3
# 47   2001807931  1091117327172                  0.607            1
# 52   2001807981  1091117327570                  0.500            1
# 55   2001808207  1091117435370                  0.607            1
# 57   2001808295  1091117435661                  0.245            1
# 60   2001808542  1091117436464                  0.734            1
# 61   2001808585  1091117436652                  0.500            1
# 62   2001808675  1091117437050                  1.183            3
# 71   2001809383  1091117614452                  0.607            2
# 72   2001809592  1091117616121                  1.505            4
# 76   2001809934  1091117803511                  0.361            1
# 77   2001810104  1091117804200                  0.601            2
# 86   2001811229  1091117957942                  0.505            2
# 87   2001811305  1091121846136                  0.750            2
# 91   2001811475  1091121844806                  0.689            1
# 92   2001811604  1091118004245                  0.721            1
# 95   2001812650  1091118591534                  0.563            2
# 96   2001812838  1091118547832                  0.558            2
# 97   2001812854  1091118548333                  2.572            6
# 99   2001813009  1091118553701                  0.720            2
# 101  2001815688  1091119169701                  0.220            1
# 105  2001817093  1091121485824                  1.357            3
# 107  2001818390  1091120014461                  0.841            1
# 108  2001819252  1091120352712                  0.270            1
# 110  2001820978  1091120922803                  0.515            2
# 111  2001821185  1091120959225                  2.098            5
# 113  2001821284  1091120962515                  0.177            1
# 115  2001821679  1091121031745                  0.165            1
# 120  2001822466  1091121305541                  1.376            3
# 123  2001827036  1091122418320                  2.176            2
#
#      Total weight as per Courier Company (KG)  \
# 1                                        0.68
# 2                                        0.71
# 3                                        1.30
# 6                                        1.00
# 12                                       1.70
# 15                                       1.16
# 16                                       0.68
# 17                                       1.08
# 18                                       0.69
# 19                                       0.15
# 20                                       0.68
# 23                                       1.02
# 28                                       1.00
# 32                                       1.64
# 41                                       1.00
# 47                                       0.72
# 52                                       0.50
# 55                                       0.79
# 57                                       0.20
# 60                                       0.86
# 61                                       0.72
# 62                                       1.20
# 71                                       0.50
# 72                                       1.50
# 76                                       0.82
# 77                                       0.76
# 86                                       0.60
# 87                                       0.50
# 91                                       0.50
# 92                                       0.80
# 95                                       0.61
# 96                                       0.60
# 97                                       2.94
# 99                                       1.00
# 101                                      0.20
# 105                                      1.30
# 107                                      0.80
# 108                                      0.30
# 110                                      0.50
# 111                                      2.10
# 113                                      0.20
# 115                                      0.20
# 120                                      1.10
# 123                                      1.60
#
#      Weight slab charged by Courier Company (KG) DeliveryZoneasperX  \
# 1                                              1                  d
# 2                                              1                  d
# 3                                              3                  d
# 6                                              1                  d
# 12                                             4                  b
# 15                                             3                  d
# 16                                             2                  b
# 17                                             3                  b
# 18                                             2                  d
# 19                                             1                  d
# 20                                             2                  d
# 23                                             1                  b
# 28                                             1                  b
# 32                                             4                  d
# 41                                             1                  b
# 47                                             2                  d
# 52                                             1                  b
# 55                                             2                  d
# 57                                             1                  e
# 60                                             1                  d
# 61                                             2                  e
# 62                                             1                  b
# 71                                             1                  b
# 72                                             3                  b
# 76                                             2                  b
# 77                                             2                  b
# 86                                             2                  b
# 87                                             1                  b
# 91                                             1                  e
# 92                                             2                  e
# 95                                             2                  b
# 96                                             2                  b
# 97                                             6                  b
# 99                                             2                  b
# 101                                            1                  b
# 105                                            3                  b
# 107                                            2                  e
# 108                                            1                  e
# 110                                            1                  b
# 111                                            5                  b
# 113                                            1                  b
# 115                                            1                  b
# 120                                            1                  b
# 123                                            4                  e
#
#     Delivery Zone charged by Courier Company  ExpectedChargeasperX(Rs.)  \
# 1                                          d                     101.65
# 2                                          d                      99.50
# 3                                          d                     197.15
# 6                                          d                     129.60
# 12                                         d                     330.05
# 15                                         d                     245.20
# 16                                         b                      87.10
# 17                                         b                     215.25
# 18                                         d                      99.50
# 19                                         d                      75.55
# 20                                         d                      99.50
# 23                                         d                     167.95
# 28                                         b                     253.30
# 32                                         d                     600.50
# 41                                         b                      89.60
# 47                                         d                     115.35
# 52                                         d                      87.10
# 55                                         d                     115.35
# 57                                         e                     181.60
# 60                                         d                     128.95
# 61                                         b                     110.70
# 62                                         b                     266.85
# 71                                         d                     110.10
# 72                                         b                     117.90
# 76                                         d                     111.10
# 77                                         d                     169.55
# 86                                         d                     161.50
# 87                                         d                     173.60
# 91                                         b                     157.10
# 92                                         b                     156.75
# 95                                         d                     194.45
# 96                                         b                     242.25
# 97                                         d                     548.45
# 99                                         d                     181.60
# 101                                        d                      99.20
# 105                                        b                     556.80
# 107                                        e                     215.50
# 108                                        b                      56.60
# 110                                        d                      61.30
# 111                                        d                     385.65
# 113                                        d                      93.55
# 115                                        d                      56.50
# 120                                        d                     540.55
# 123                                        b                     294.10
#
#      Charges Billed by Courier Company (Rs.)  \
# 1                                       90.2
# 2                                       90.2
# 3                                      140.0
# 6                                      101.2
# 12                                     179.8
# 15                                     141.0
# 16                                      71.3
# 17                                      98.6
# 18                                      90.2
# 19                                      45.4
# 20                                      90.2
# 23                                     146.0
# 28                                      61.3
# 32                                     179.8
# 41                                      61.3
# 47                                      97.2
# 52                                      53.4
# 55                                      90.2
# 57                                     127.3
# 60                                     101.2
# 61                                      61.3
# 62                                      89.6
# 71                                      86.7
# 72                                      89.6
# 76                                      98.2
# 77                                      90.2
# 86                                      93.2
# 87                                      65.4
# 91                                      47.0
# 92                                      67.3
# 95                                      90.2
# 96                                     108.3
# 97                                     280.4
# 99                                      92.2
# 101                                     45.4
# 105                                    166.1
# 107                                    213.5
# 108                                     33.0
# 110                                     45.4
# 111                                    224.6
# 113                                     45.4
# 115                                     52.4
# 120                                    135.0
# 123                                    117.9
#
#      Difference Between Expected Charges and Billed Charges (Rs.)
# 1                                                11.45
# 2                                                 9.30
# 3                                                57.15
# 6                                                28.40
# 12                                              150.25
# 15                                              104.20
# 16                                               15.80
# 17                                              116.65
# 18                                                9.30
# 19                                               30.15
# 20                                                9.30
# 23                                               21.95
# 28                                              192.00
# 32                                              420.70
# 41                                               28.30
# 47                                               18.15
# 52                                               33.70
# 55                                               25.15
# 57                                               54.30
# 60                                               27.75
# 61                                               49.40
# 62                                              177.25
# 71                                               23.40
# 72                                               28.30
# 76                                               12.90
# 77                                               79.35
# 86                                               68.30
# 87                                              108.20
# 91                                              110.10
# 92                                               89.45
# 95                                              104.25
# 96                                              133.95
# 97                                              268.05
# 99                                               89.40
# 101                                              53.80
# 105                                             390.70
# 107                                               2.00
# 108                                              23.60
# 110                                              15.90
# 111                                             161.05
# 113                                              48.15
# 115                                               4.10
# 120                                             405.55
# 123                                             176.20

# %%
Undercharge_Count=len(Undercharge.index)

# %%
Undercharge_Count
# Out:
# 44

# %%
Undercharge_Sum=Undercharge['Difference Between Expected Charges and Billed Charges (Rs.)'].sum()

# %%
Undercharge_Sum
# Out:
# 3987.3

# %%
summary=['Count','Amount(Rs.)']

# %%
summary
# Out:
# ['Count', 'Amount(Rs.)']

# %%
data=[['Total orders where X has been correctly charged',10,577.6999999999999],
      ['Total Orders where X has been overcharged',70,4178.700000000001],
      ['Total Orders where X has been undercharged',44,3987.3]]

# %%
Summary = pd.DataFrame(data, columns=['','Count','Amount(Rs.)'])

# %%
Summary
# Out:
#                                                     Count  Amount(Rs.)
# 0  Total orders where X has been correctly charged     10        577.7
# 1        Total Orders where X has been overcharged     70       4178.7
# 2       Total Orders where X has been undercharged     44       3987.3

# %%
Summary.to_excel('Output_data_2.xlsx')

# %%
final.to_excel('Output_Data_1.xlsx')
